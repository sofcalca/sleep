# %%
from sys import platform as _platform
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_columns', None)
#if _platform =='linux2':
#    path = '../data/data_sleep/' 
#else:
#    #mets ton path ici et ça devrait marcher :)
#    path = ""
path = "data/"

# %%
#frequencies=pd.read_csv(path+"data_frequences.csv").drop("Unnamed: 0", axis=1)
frequencies=pd.read_csv(path+"fft_eeg.csv")
frequencies_acc =pd.read_csv(path+"fft_acc.csv")

stats_acc=pd.read_csv(path+"stats_acc.csv")
stats_egg=pd.read_csv(path+"stats_eeg.csv")
stats=pd.concat([stats_acc, stats_egg], axis=1)
#ACC_feats =pd.read_csv(path+"ACC_feats.csv").drop("Unnamed: 0", axis=1)
labels=pd.read_csv(path+"challenge_output_data_training_file_sleep_stages_classification.csv", sep=";")
#stats = pd.concat([stats.filter(regex="EEG[0-9]*"),stats_ACC], axis=1)
#stats = pd.concat([stats,stats_ACC], axis=1)

frequencies_test=pd.read_csv(path+"fft_eeg_test.csv")
frequencies_acc_test =pd.read_csv(path+"fft_acc_test.csv")
ACC_feats_test =pd.read_csv(path+"ACC_feats_test.csv")
stats_acc_test=pd.read_csv(path+"stats_acc_test.csv")
stats_egg_test=pd.read_csv(path+"stats_eeg_test.csv")
stats_test=pd.concat([stats_acc_test, stats_egg_test], axis=1)

# %%
from sklearn.cross_validation import train_test_split
frequencies,  frequencies_test=train_test_split(frequencies, test_size=0.25, random_state=42)
frequencies_acc, frequencies_acc_test=train_test_split(frequencies_acc, test_size=0.25, random_state=42)

stats_acc, stats_acc_test=train_test_split(stats_acc, test_size=0.25, random_state=42)
stats_egg, stats_egg_test=train_test_split(stats_egg, test_size=0.25, random_state=42)
stats=pd.concat([stats_acc, stats_egg], axis=1)
del stats_acc, stats_egg
stats_test=pd.concat([stats_acc_test, stats_egg_test], axis=1)
del stats_acc_test, stats_egg_test
#ACC_feats =pd.read_csv(path+"ACC_feats.csv").drop("Unnamed: 0", axis=1)
labels, labels_test=train_test_split(labels, test_size=0.25, random_state=42)

# %%
def select_freq_names(low, high, X_columns, prefix = ''):
    return [name for name in X_columns 
            if len(name.split('q'))==2 
            and name.split('freq')[0] == prefix
            and low<=float(name.split('freq')[1]) 
            and high>= float(name.split('freq')[1])]
def group_frequencies(name, low, high, frequencies, prefix = ''):
    frequencies[name]=(1./(high-low) * (frequencies[select_freq_names(low,high,frequencies.columns,prefix)])).sum(axis=1)

# %%
#frequencies["delta"]=frequencies[select_freq_names(0,3,frequencies.columns)].sum(axis=1)
#frequencies["delta"]=frequencies[select_freq_names(0,3.99,frequencies.columns)].sum(axis=1)
#frequencies["theta"]=frequencies[select_freq_names(4,7.5,frequencies.columns)].sum(axis=1)
#frequencies["alpha"]=frequencies[select_freq_names(7.5,13.99,frequencies.columns)].sum(axis=1)
#frequencies["beta"]=frequencies[select_freq_names(14,50,frequencies.columns)].sum(axis=1)

def make_new_feats(frequencies):
    group_frequencies("delta1", 0.4, 0.8, frequencies)
    group_frequencies("delta2", 0.81, 1.99, frequencies)
    group_frequencies("delta3", 2, 3.99, frequencies)
    group_frequencies("theta1", 4, 5, frequencies)
    group_frequencies("theta2", 5, 7.499, frequencies)
    group_frequencies("alpha1", 7.5, 9.5, frequencies)
    group_frequencies("alpha2", 9.5, 10.499, frequencies)
    group_frequencies("alpha3", 10.5, 13.5, frequencies)
    group_frequencies("beta", 14, 20, frequencies)
    group_frequencies("beta2", 20, 30, frequencies)
    group_frequencies("beta3", 31, 50, frequencies)

# %%
def regroup_acc_freq (frequencies_acc):
    for prefix in ['ACC_X.','ACC_Y.','ACC_Z.']:
        group_frequencies(prefix+"smaller_one",0.01,1, frequencies_acc,prefix)
        group_frequencies(prefix+"one_to_two",1.01,2, frequencies_acc,prefix)
        group_frequencies(prefix+"two_to_three",2.01,3, frequencies_acc,prefix)
        group_frequencies(prefix+"three_to_four",3.01,4, frequencies_acc,prefix)
        group_frequencies(prefix+"more_four",4,10, frequencies_acc,prefix)

# %%
def make_new_features(f, stat, f_acc):
    new_feat = ["delta1","delta2","delta3", 'theta1', 'theta2', 'alpha1','alpha2','alpha3', 'beta','beta2','beta3']
    make_new_feats(f)
    
    prefixes = ['ACC_X.','ACC_Y.','ACC_Z.']
    regroup_acc_freq (f_acc)
    frequencies_acc2 = f_acc[[prefix+ x for x in["smaller_one","one_to_two","two_to_three",'more_four']for prefix in prefixes]]
    
    return  pd.concat([f[new_feat], stat, frequencies_acc2], axis=1)

# %%
train = make_new_features(frequencies, stats, frequencies_acc)
test = make_new_features(frequencies_test, stats_test, frequencies_acc_test)

# %%
train.describe()
# Out:
#              delta1           delta2           delta3           theta1  \
# count  3.112900e+04     31129.000000     31129.000000     31129.000000
# mean   2.180787e+05     66415.984901     25777.882487     16727.005791
# std    1.049126e+06    401127.379008    193613.862060    130811.552912
# min    8.735729e+03      7379.103464      3799.285076      3239.585741
# 25%    6.197437e+04     27329.731884     14956.410902     10663.517299
# 50%    1.231523e+05     49314.516471     20900.627362     13999.200839
# 75%    2.428998e+05     88949.671332     30823.429075     19183.811642
# max    1.800878e+08  70332976.346025  34095712.393256  23045297.512860
#
#                 theta2           alpha1          alpha2          alpha3  \
# count     31129.000000     31129.000000    31129.000000    31129.000000
# mean      12412.698942     10436.192508     9230.629203     7652.617749
# std       90632.399730     65039.692153    55269.180990    46207.481534
# min        2820.366473      2488.058337     1788.434487     1849.995240
# 25%        8450.038038      6834.118876     5741.838036     5180.077931
# 50%       10678.473484      8865.193597     7686.463766     6817.801432
# 75%       13929.248469     12152.487994    10673.174154     8812.849217
# max    15966724.175358  11448208.252360  9719435.594529  8136543.694344
#
#                  beta           beta2           beta3  ACC_X_quantile_0  \
# count    31129.000000    31129.000000    31129.000000      31129.000000
# mean      4395.367835     3076.966534     2217.256648     463043.459858
# std      33265.198819    22897.909771    14408.527366     586520.188548
# min       1278.448601      807.117998      498.179195          0.000000
# 25%       2914.963723     1903.384050     1255.601428          0.000000
# 50%       3581.734558     2260.577019     1451.800524     200501.676575
# 75%       4551.636660     2973.881455     2135.164488    1245765.946220
# max    5853859.595836  4013275.714700  2496438.831388    1677640.565260
#
#        ACC_X_quantile_10  ACC_X_quantile_20  ACC_X_quantile_30  \
# count       31129.000000       31129.000000       31129.000000
# mean       467174.530536      474999.947300      492067.066492
# std        587923.715579      583843.126280      575799.732902
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%        207219.445857      220269.167027      285037.057026
# 75%       1247935.344330     1248558.781110     1248973.446340
# max       1677951.780770     1678947.447500     1679335.338040
#
#        ACC_X_quantile_40  ACC_X_quantile_50  ACC_X_quantile_60  \
# count       31129.000000       31129.000000       31129.000000
# mean       512800.096769      534592.475148      556714.590114
# std        571903.857252      576135.801496      588850.829758
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%        325482.690940      331870.768185      332820.496128
# 75%       1249024.790550     1249045.440790     1249050.462650
# max       1679647.405820     1680023.506520     1680340.821460
#
#        ACC_X_quantile_70  ACC_X_quantile_80  ACC_X_quantile_90  \
# count       31129.000000       31129.000000       31129.000000
# mean       578462.955919      599379.979357      614626.710998
# std        609066.069517      634782.817990      656140.274833
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%        333500.145122      334949.232906      335403.784965
# 75%       1269089.470600     1299826.224730     1302429.700470
# max       1681770.266940     1682160.723500     1682321.069130
#
#        ACC_X_quantile_100      mean_ACC_X     var_ACC_X    skew_ACC_X  \
# count        31129.000000    31129.000000  3.112900e+04  3.105900e+04
# mean        619450.027578   537272.507188  3.330232e+10 -9.025399e+04
# std         661408.888219   576190.718726  1.071621e+11  3.791622e+06
# min              0.000000        0.000000  0.000000e+00 -2.384430e+08
# 25%              0.000000        0.000000  0.000000e+00 -9.853041e-02
# 50%         336024.663968   332471.073121  7.926813e+04  0.000000e+00
# 75%        1302794.057530  1248824.166290  4.934285e+05  1.030035e-01
# max        1682421.220660  1678497.393070  6.166753e+11  9.353668e+05
#
#          kurt_ACC_X  ACC_Y_quantile_0  ACC_Y_quantile_10  ACC_Y_quantile_20  \
# count  3.112900e+04      31129.000000       31129.000000       31129.000000
# mean  -4.718321e+13     508458.001608      512433.331547      520669.693936
# std    1.858705e+15     670905.568374      672213.290684      668321.467589
# min   -6.333526e+16          0.000000           0.000000           0.000000
# 25%   -4.718182e-01          0.000000           0.000000           0.000000
# 50%    0.000000e+00      71380.506729       79465.537309      101229.183762
# 75%    1.569532e-01    1391781.490910     1395128.072550     1401799.786780
# max    3.841563e+16    1678843.737320     1679413.596860     1679591.932640
#
#        ACC_Y_quantile_30  ACC_Y_quantile_40  ACC_Y_quantile_50  \
# count       31129.000000       31129.000000       31129.000000
# mean       538912.377147      560303.097796      583160.354622
# std        660155.944471      655888.106042      658494.868185
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%        149120.401618      162388.346131      166062.022173
# 75%       1403900.532040     1405352.141420     1405636.579820
# max       1679770.554930     1680077.181540     1680958.583470
#
#        ACC_Y_quantile_60  ACC_Y_quantile_70  ACC_Y_quantile_80  \
# count       31129.000000       31129.000000       31129.000000
# mean       606010.389134      628979.842747      650082.743408
# std        668761.620419      686526.242650      708558.016987
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%        166749.380713      167591.188036      168669.216002
# 75%       1405869.241000     1412457.320780     1487671.497720
# max       1681100.457470     1681604.195970     1682233.092470
#
#        ACC_Y_quantile_90  ACC_Y_quantile_100      mean_ACC_Y     var_ACC_Y  \
# count       31129.000000        31129.000000    31129.000000  3.112900e+04
# mean       665331.568056       670117.303174   585548.917565  3.488588e+10
# std        726915.544490       729208.429707   657677.633921  1.104874e+11
# min             0.000000            0.000000        0.000000  0.000000e+00
# 25%             0.000000            0.000000        0.000000  0.000000e+00
# 50%        170834.217283       180041.535579   168331.881284  1.316513e+05
# 75%       1526567.382960      1529385.905650  1403606.253900  6.407979e+05
# max       1682330.681370      1682421.220660  1679751.107980  6.287287e+11
#
#             skew_ACC_Y    kurt_ACC_Y  ACC_Z_quantile_0  ACC_Z_quantile_10  \
# count     31095.000000  3.112900e+04      31129.000000       31129.000000
# mean     -44216.596762  7.224458e+13     389079.403871      394942.680469
# std     2012175.965070  2.258636e+15     561598.622147      565504.824485
# min   -91635309.917200 -1.061277e+16          0.000000           0.000000
# 25%          -0.118877 -5.902069e-01          0.000000           0.000000
# 50%           0.000000  0.000000e+00      91639.477349       98201.173482
# 75%           0.078766  1.249703e-01     424299.974866      426528.414206
# max      268860.079436  7.371408e+16    1678757.317340     1680153.808660
#
#        ACC_Z_quantile_20  ACC_Z_quantile_30  ACC_Z_quantile_40  \
# count       31129.000000       31129.000000       31129.000000
# mean       401722.919196      418578.215755      441054.816154
# std        564376.304941      559270.237759      557448.144970
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%        116428.759178      170002.357958      192316.672991
# 75%        426645.396649      432124.918890      582170.599627
# max       1680473.853470     1680593.335530     1680729.325810
#
#        ACC_Z_quantile_50  ACC_Z_quantile_60  ACC_Z_quantile_70  \
# count       31129.000000       31129.000000       31129.000000
# mean       464406.560797      487958.291960      511829.372506
# std        564465.259308      581027.070964      606772.710146
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%        193780.850891      193954.602202      194124.333302
# 75%        808454.196385      986527.545088     1224155.753420
# max       1680813.125630     1680938.709620     1682200.457600
#
#        ACC_Z_quantile_80  ACC_Z_quantile_90  ACC_Z_quantile_100  \
# count       31129.000000       31129.000000        31129.000000
# mean       533244.536975      548457.120201       553119.307859
# std        635475.764328      658244.766881       662057.095991
# min             0.000000           0.000000            0.000000
# 25%             0.000000           0.000000            0.000000
# 50%        194804.309533      195515.181404       198939.906894
# 75%       1306315.719800     1310768.407150      1317054.647870
# max       1682284.836810     1682347.954830      1682421.220660
#
#            mean_ACC_Z     var_ACC_Z    skew_ACC_Z    kurt_ACC_Z  \
# count    31129.000000  3.112900e+04  3.112700e+04  3.112900e+04
# mean    467403.641997  3.551936e+10 -1.056223e+05  4.234130e+12
# std     564113.518866  1.127120e+11  2.484497e+06  3.619110e+14
# min          0.000000  0.000000e+00 -1.798704e+08 -4.018160e+14
# 25%          0.000000  0.000000e+00  0.000000e+00 -4.857886e-01
# 50%     194144.996143  7.880265e+04  0.000000e+00  0.000000e+00
# 75%     810118.297996  9.166023e+05  1.920846e-01  2.069295e-01
# max    1679657.071140  6.255575e+11  8.269454e+04  3.546717e+16
#
#        EEG_quantile_0  EEG_quantile_10  EEG_quantile_20  EEG_quantile_30  \
# count    31129.000000     31129.000000     31129.000000     31129.000000
# mean       -67.668904       -24.578816       -15.029817        -9.142491
# std        332.438831        44.725172        16.280377         9.902244
# min     -57846.411752     -6473.418040      -370.417062      -133.772751
# 25%        -82.958289       -27.823264       -17.027716       -10.307362
# 50%        -47.309534       -14.675546        -8.980321        -5.521182
# 75%        -27.449899        -9.012322        -5.747950        -3.609769
# max         -7.846800        -3.336069        -2.250318        -1.371010
#
#        EEG_quantile_40  EEG_quantile_50  EEG_quantile_60  EEG_quantile_70  \
# count     31129.000000     31129.000000     31129.000000     31129.000000
# mean         -4.553969        -0.429837         3.709411         8.344859
# std           5.071556         1.948052         4.814270         9.619773
# min         -79.882920       -33.425067        -9.044022         1.006095
# 25%          -5.068524        -0.757524         1.227857         3.012414
# 50%          -2.746643        -0.332591         2.027671         4.745264
# 75%          -1.838396         0.045524         4.116302         9.476140
# max           1.549733        26.079463        74.284299       121.039011
#
#        EEG_quantile_80  EEG_quantile_90  EEG_quantile_100      mean_EEG  \
# count     31129.000000     31129.000000      31129.000000  31129.000000
# mean         14.295154        23.852064         70.926835     -0.307724
# std          15.967630        29.583928        955.988966      0.960328
# min           1.760171         2.963225          7.786749    -12.641050
# 25%           5.146811         8.339893         26.976275     -0.528154
# 50%           8.242451        14.058969         47.394753     -0.315067
# 75%          16.365352        27.402314         82.504026     -0.019021
# max         189.060611      2530.299222     168434.316703     14.288895
#
#             var_EEG      skew_EEG      kurt_EEG  EEG_through_0  \
# count  3.112900e+04  31129.000000  31129.000000   31129.000000
# mean   8.091409e+03      0.042390      1.888080     266.303897
# std    1.286930e+06      0.536758      4.737300     258.887286
# min    6.358505e+00     -9.909720     -1.469313      11.000000
# 25%    5.498961e+01     -0.187791      0.122153     109.000000
# 50%    1.701812e+02      0.026829      0.685011     204.000000
# 75%    5.387287e+02      0.261775      1.900467     318.000000
# max    2.270588e+08     13.196885    305.230097    3008.000000
#
#        ACC_X.smaller_one  ACC_Y.smaller_one  ACC_Z.smaller_one  \
# count       31129.000000       31129.000000       31129.000000
# mean        55257.764563       59060.369738       68198.799131
# std        185354.795972      194231.355360      219370.283315
# min             0.000000           0.000000           0.000000
# 25%             0.000000           0.000000           0.000000
# 50%           291.346883         399.276609         305.079191
# 75%           852.121895        1225.520195        1299.806604
# max       1520394.435876     1495382.004802     1526600.035678
#
#        ACC_X.one_to_two  ACC_Y.one_to_two  ACC_Z.one_to_two  \
# count      31129.000000      31129.000000      31129.000000
# mean       45070.254993      46029.634280      52876.211177
# std       149501.520258     148640.948015     169063.960230
# min            0.000000          0.000000          0.000000
# 25%            0.000000          0.000000          0.000000
# 50%          167.775517        194.342400        176.853885
# 75%          291.793296        325.416886        356.170923
# max      1063447.474825     977418.806628     997320.652283
#
#        ACC_X.two_to_three  ACC_Y.two_to_three  ACC_Z.two_to_three  \
# count        31129.000000        31129.000000        31129.000000
# mean         58954.750214        60437.381404        57634.399315
# std         197487.618553       197422.005196       186300.527832
# min              0.000000            0.000000            0.000000
# 25%              0.000000            0.000000            0.000000
# 50%            191.628418          235.663850          204.715626
# 75%            394.255615          434.043896          485.958391
# max        1342173.502363      1288287.269416      1117223.001579
#
#        ACC_X.more_four  ACC_Y.more_four  ACC_Z.more_four
# count     31129.000000     31129.000000     31129.000000
# mean       6722.761692      6419.831198      7002.951855
# std       22455.088518     20677.336291     22213.360958
# min           0.000000         0.000000         0.000000
# 25%           0.000000         0.000000         0.000000
# 50%          42.828857        53.168973        47.047349
# 75%          90.726118        94.976595       103.744164
# max      163937.806183    165207.506982    163803.108806

# %%
test.describe()
# Out:
#              delta1        delta2        delta3        theta1        theta2  \
# count  30458.000000  30458.000000  30458.000000  30458.000000  30458.000000
# mean      51.873624     17.992502      6.794295      4.340244      3.167898
# std       54.592059     13.205135      3.736462      2.131689      1.404761
# min        2.497837      1.429470      1.092056      0.877469      0.780968
# 25%       16.459045      7.464735      4.033262      2.840301      2.186732
# 50%       33.391036     14.140029      5.962989      3.959438      2.944762
# 75%       63.943894     25.276051      8.679110      5.375004      3.871193
# max      536.194425    150.419599     68.867623     46.639139     30.932185
#
#              alpha1        alpha2        alpha3          beta         beta2  \
# count  30458.000000  30458.000000  30458.000000  30458.000000  30458.000000
# mean       2.499432      2.196317      1.872309      1.083713      0.781358
# std        1.241717      1.140811      0.832338      0.544895      0.509729
# min        0.624017      0.486431      0.482011      0.359787      0.196081
# 25%        1.684267      1.457726      1.289168      0.774011      0.528792
# 50%        2.300503      1.989302      1.757593      0.963472      0.638316
# 75%        3.040303      2.656283      2.291980      1.235559      0.854534
# max       37.065072     37.824970     15.861666     12.292842     11.661012
#
#               beta3  ACC_X_quantile_0  ACC_X_quantile_10  ACC_X_quantile_20  \
# count  30458.000000      30458.000000       30458.000000       30458.000000
# mean       0.563860     563610.290791      567084.633856      577435.056470
# std        0.592141     619457.702821      619562.521660      612280.442131
# min        0.110927          0.000000           0.000000           0.000000
# 25%        0.349798         16.846644         189.359716        6642.127578
# 50%        0.406077     296879.876933      298148.361672      298979.536672
# 75%        0.583657    1294511.801902     1296560.754850     1296980.013885
# max       24.706281    1679563.746220     1679985.280670     1680453.858690
#
#        ACC_X_quantile_30  ACC_X_quantile_40  ACC_X_quantile_50  \
# count       30458.000000       30458.000000       30458.000000
# mean       601765.952872      635351.414288      671050.579973
# std        596534.214003      581737.122153      577926.703959
# min             0.000000           0.000000           0.000000
# 25%         83502.984436      123819.822703      124610.083599
# 50%        323868.455626      393153.110669      451425.931005
# 75%       1297121.795263     1297489.986380     1297700.977913
# max       1680528.250550     1680639.317020     1680784.204370
#
#        ACC_X_quantile_60  ACC_X_quantile_70  ACC_X_quantile_80  \
# count       30458.000000       30458.000000       30458.000000
# mean       707440.210060      744038.631187      779255.487619
# std        587184.991182      609209.818331      640521.195853
# min             0.000000           0.000000           0.000000
# 25%        127608.657668      135103.012824      140929.526216
# 50%        460634.530590      479451.553818      480364.648878
# 75%       1298534.194525     1304886.048260     1397139.785267
# max       1680875.359220     1681002.521200     1682221.219240
#
#        ACC_X_quantile_90  ACC_X_quantile_100      mean_ACC_X     var_ACC_X  \
# count       30458.000000        30458.000000    30458.000000  3.045800e+04
# mean       807892.068274       815905.409883   678133.310874  5.457041e+10
# std        671721.534660       678037.978785   576678.553613  1.328382e+11
# min             0.000000            0.000000        0.000000  0.000000e+00
# 25%        141264.576857       142140.279036   137131.895118  3.187273e+04
# 50%        481234.665396       483808.220366   479409.810720  1.327347e+05
# 75%       1450514.863535      1453254.446630  1297503.268940  7.236601e+05
# max       1682369.020960      1682421.220660  1680304.986490  6.494654e+11
#
#             skew_ACC_X    kurt_ACC_X  ACC_Y_quantile_0  ACC_Y_quantile_10  \
# count     30458.000000  3.045800e+04      30458.000000       30458.000000
# mean     -11410.973991  6.644445e+11     552288.799338      557927.042470
# std      808430.175061  4.807920e+13     681836.912157      683381.254168
# min   -72130536.592900 -1.391810e+08          0.000000           0.000000
# 25%          -0.121687 -7.845276e-01         36.717679         328.995710
# 50%           0.000000  0.000000e+00     129318.920232      132660.731240
# 75%           0.171166  2.125294e-01    1420688.191277     1422207.873667
# max          77.040892  4.397221e+15    1677119.378770     1679554.539900
#
#        ACC_Y_quantile_20  ACC_Y_quantile_30  ACC_Y_quantile_40  \
# count       30458.000000       30458.000000       30458.000000
# mean       572286.779482      601085.387311      635182.176917
# std        675428.557810      659786.874618      649089.426501
# min             0.000000           0.000000           0.000000
# 25%         23862.306409       58187.756038       65791.121402
# 50%        155736.314956      231367.127186      316215.073389
# 75%       1423277.106920     1424448.189217     1425861.562213
# max       1679859.256080     1680124.276560     1680222.769720
#
#        ACC_Y_quantile_50  ACC_Y_quantile_60  ACC_Y_quantile_70  \
# count       30458.000000       30458.000000       30458.000000
# mean       670568.047277      706392.329323      742101.057054
# std        648333.716867      658702.353746      679649.824010
# min             0.000000           0.000000           0.000000
# 25%         66494.020917       67172.109897       67952.215625
# 50%        321004.110026      323230.938782      323373.930182
# 75%       1426563.386385     1428745.168745     1429496.714395
# max       1680356.043300     1680528.016080     1680670.141870
#
#        ACC_Y_quantile_80  ACC_Y_quantile_90  ACC_Y_quantile_100  \
# count       30458.000000       30458.000000        30458.000000
# mean       775371.803300      802288.424375       810697.845677
# std        707579.091081      734768.551478       740065.079932
# min             0.000000           0.000000            0.000000
# 25%         68463.661086       68910.469048        71503.088807
# 50%        323496.494083      323657.571448       331961.642090
# 75%       1501940.434923     1580047.398588      1597445.171285
# max       1682155.090620     1682315.836180      1682421.220660
#
#            mean_ACC_Y     var_ACC_Y    skew_ACC_Y    kurt_ACC_Y  \
# count    30458.000000  3.045800e+04  3.045800e+04  3.045800e+04
# mean    674523.009937  5.458737e+10 -6.816553e+03  6.818055e+11
# std     646824.532816  1.317086e+11  8.410267e+05  8.413946e+13
# min          0.000000  0.000000e+00 -1.037893e+08 -3.770066e+11
# 25%      67750.790179  6.383864e+04 -9.024594e-02 -8.331776e-01
# 50%     323240.464067  2.114918e+05  0.000000e+00  0.000000e+00
# 75%    1424327.117208  1.812563e+06  1.811394e-01  2.271130e-01
# max    1678384.632210  6.478127e+11  1.967733e+04  1.038347e+16
#
#        ACC_Z_quantile_0  ACC_Z_quantile_10  ACC_Z_quantile_20  \
# count      30458.000000       30458.000000       30458.000000
# mean      465696.911817      469407.635961      479328.821356
# std       611918.188137      613091.055042      608077.877470
# min            0.000000           0.000000           0.000000
# 25%           11.464322         157.566424         534.573457
# 50%       159516.894451      161077.514834      175821.047393
# 75%      1057086.423632     1267220.125717     1268695.269630
# max      1677367.269150     1679111.946500     1679783.328130
#
#        ACC_Z_quantile_30  ACC_Z_quantile_40  ACC_Z_quantile_50  \
# count       30458.000000       30458.000000       30458.000000
# mean       503049.706907      537145.351262      573888.496563
# std        596350.094318      586209.146948      587664.316146
# min             0.000000           0.000000           0.000000
# 25%         41721.497226       66220.072297       66552.228315
# 50%        236810.139750      323367.271164      360706.260994
# 75%       1271104.015050     1271493.337230     1272108.662138
# max       1680009.155230     1680213.083450     1680450.353810
#
#        ACC_Z_quantile_60  ACC_Z_quantile_70  ACC_Z_quantile_80  \
# count       30458.000000       30458.000000       30458.000000
# mean       611873.577913      649789.417138      685949.469918
# std        602988.678536      631013.020791      667451.444903
# min             0.000000           0.000000           0.000000
# 25%         66855.880727       67203.845177       67479.773526
# 50%        363099.173598      364959.922201      365951.126500
# 75%       1276850.699230     1340569.761565     1450771.860977
# max       1680581.567260     1680831.051480     1682239.387520
#
#        ACC_Z_quantile_90  ACC_Z_quantile_100      mean_ACC_Z     var_ACC_Z  \
# count       30458.000000        30458.000000    30458.000000  3.045800e+04
# mean       713448.177243       723819.286615   581850.570548  5.574086e+10
# std        699449.896686       705652.744794   587771.660778  1.355721e+11
# min             0.000000            0.000000        0.000000  0.000000e+00
# 25%         67961.650246        70532.131977    66823.468343  3.800183e+04
# 50%        366395.641735       373407.755144   362187.490558  1.958548e+05
# 75%       1516014.841568      1530076.909905  1271433.283242  1.310939e+06
# max       1682359.648110      1682421.220660  1679158.629880  6.242328e+11
#
#          skew_ACC_Z    kurt_ACC_Z  EEG_quantile_0  EEG_quantile_10  \
# count  3.045700e+04  3.045800e+04    30458.000000     30458.000000
# mean  -5.445095e+04  7.059670e+12      -63.373048       -22.649193
# std    3.208139e+06  4.242232e+14       59.401047        20.491297
# min   -2.053745e+08 -6.150130e+15    -3919.092052      -228.808143
# 25%   -1.273722e-01 -9.230886e-01      -79.878237       -28.255981
# 50%    0.000000e+00 -4.178308e-02      -48.297646       -15.398113
# 75%    1.988846e-01  1.754498e-01      -27.876971        -9.180518
# max    5.953723e+03  2.604053e+16       -7.005713        -2.759135
#
#        EEG_quantile_20  EEG_quantile_30  EEG_quantile_40  EEG_quantile_50  \
# count     30458.000000     30458.000000     30458.000000     30458.000000
# mean        -14.037461        -8.625256        -4.343720        -0.455796
# std          12.729963         7.824831         4.102784         1.617159
# min        -142.650384       -87.188496       -54.782444       -27.513419
# 25%         -17.520982       -10.689840        -5.268655        -0.784237
# 50%          -9.443286        -5.798343        -2.909313        -0.363786
# 75%          -5.864025        -3.688422        -1.899536         0.021682
# max          -1.802765        -1.027713         2.110239        23.455692
#
#        EEG_quantile_60  EEG_quantile_70  EEG_quantile_80  EEG_quantile_90  \
# count     30458.000000     30458.000000     30458.000000     30458.000000
# mean          3.454877         7.798586        13.280475        22.032783
# std           3.701978         7.530037        12.565162        20.686611
# min          -5.686633         0.884839         1.695330         2.707920
# 25%           1.218034         3.014442         5.166714         8.442580
# 50%           2.119788         5.026527         8.657511        14.554369
# 75%           4.254077         9.784900        16.681268        27.762387
# max          52.677120        92.130091       132.125968       237.136888
#
#        EEG_quantile_100      mean_EEG       var_EEG      skew_EEG  \
# count      30458.000000  30458.000000  30458.000000  30458.000000
# mean          64.157176     -0.329917    618.463526      0.059365
# std           63.232133      0.803363   1315.558871      0.498939
# min            6.341373     -9.597335      4.599795     -7.941372
# 25%           26.953455     -0.541358     57.017206     -0.173964
# 50%           48.464839     -0.350313    180.717152      0.032169
# 75%           81.182539     -0.066110    554.181431      0.258544
# max         4871.606842     15.411120  64610.055360     11.458717
#
#            kurt_EEG  EEG_through_0  ACC_X.smaller_one  ACC_Y.smaller_one  \
# count  30458.000000   30458.000000       30458.000000       30458.000000
# mean       1.787492     295.440935       88299.482826       88500.440793
# std        4.579542     266.688863      228107.000279      225461.781985
# min       -1.274602      13.000000           0.000000           0.000000
# 25%        0.096675     119.000000         190.061721         245.706857
# 50%        0.626631     232.000000         359.054049         536.087943
# 75%        1.873395     381.000000        1212.234765        1962.169681
# max      190.193451    2972.000000     1597549.361162     1470257.859103
#
#        ACC_Z.smaller_one  ACC_X.one_to_two  ACC_Y.one_to_two  \
# count       30458.000000      30458.000000      30458.000000
# mean        95394.274575      81514.311799      73358.578653
# std        235984.686756     209346.674679     185589.738172
# min             0.000000          0.000000          0.000000
# 25%           211.873628        135.036007        165.158301
# 50%           474.604889        180.385740        224.546272
# 75%          1745.444211        362.567212        417.313604
# max       1585229.726617    1170118.638086    1169292.188952
#
#        ACC_Z.one_to_two  ACC_X.two_to_three  ACC_Y.two_to_three  \
# count      30458.000000        30458.000000        30458.000000
# mean       89083.058384        92921.692146        89994.768631
# std       222943.589077       232528.629629       221963.973739
# min            0.000000            0.000000            0.000000
# 25%          149.912399          148.614776          187.615799
# 50%          202.482782          228.200829          289.303902
# 75%          410.752138          532.416319          562.958849
# max      1228585.994541      1277517.137296      1211555.209841
#
#        ACC_Z.two_to_three  ACC_X.more_four  ACC_Y.more_four  ACC_Z.more_four
# count        30458.000000     30458.000000     30458.000000     30458.000000
# mean         98861.250739     10914.984852     10595.137854     11014.606995
# std         243570.637784     27266.439021     26710.035873     27016.170489
# min              0.000000         0.000000         0.000000         0.000000
# 25%            160.881235        29.504698        42.653844        30.459539
# 50%            253.798523        65.466356        75.202613        62.395922
# 75%            539.476267       135.119474       130.935588       138.654298
# max        1284539.407579    155303.441286    154831.828693    183123.129227

# %%
from sklearn.cross_validation import train_test_split
from sklearn.preprocessing import StandardScaler
y_train = labels['TARGET']
y_test = labels_test['TARGET']
X = train.drop(["skew_ACC_X","skew_ACC_Y", "skew_ACC_Z"], axis=1)
X_t = test.drop(["skew_ACC_X","skew_ACC_Y", "skew_ACC_Z"], axis=1)
#X, X_t, y_train, y_test = train_test_split(
#    X, labels["TARGET"], test_size=0.2)

scaler = StandardScaler().partial_fit(X)
scaler = StandardScaler().partial_fit(X_t)
X_train = scaler.transform(X)
X_test = scaler.transform(X_t)
X_columns = train.columns

# %%
# %%time
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.metrics import cohen_kappa_score
et = ExtraTreesClassifier(random_state = 42,n_estimators=1000, max_depth= 29, n_jobs = 3, class_weight = 'balanced')
et.fit(X_train, y_train)
predicted_label = et.predict(X_test)

#print("Extra Random Trees - accuracy Score on test_data : ", accuracy_score(y_test, predicted_label))
print("Extra Random Trees - kappa Score on test_data : ", cohen_kappa_score(y_test, predicted_label))
print("Extra Random Trees - kappa Score on train data : ", cohen_kappa_score(y_train, et.predict(X_train)))

# %%
#from sklearn.metrics import accuracy_score
#print("Extra Random Trees - accuracy Score on test_data : ", accuracy_score(y_test, predicted_label))
#print("Extra Random Trees - kappa Score on test_data : ", cohen_kappa_score(y_test, predicted_label))

# %%
plt.figure(figsize=(15, 5))

ordering = np.argsort(et.feature_importances_)[::-1][:50]

importances = et.feature_importances_[ordering]
feature_names = X_columns[ordering]

x = np.arange(len(feature_names))
plt.bar(x, importances)
plt.xticks(x + 0.5, feature_names, rotation=90, fontsize=15);

# %%
# %%time
from sklearn.cross_validation import cross_val_score
scores = cross_val_score(et, X_train, y_train, cv=5, scoring="accuracy",n_jobs=3)
print("accuracy: {:.4f} +/-{:.4f}".format(
    np.mean(scores), np.std(scores)))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-30-b85476e40a7d> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u'from sklearn.cross_validation import cross_val_score\nscores = cross_val_score(et, X_train, y_train, cv=5, scoring="accuracy",n_jobs=3)\nprint("accuracy: {:.4f} +/-{:.4f}".format(\n    np.mean(scores), np.std(scores)))')
#
# /Users/Flukmacdesof/anaconda/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2291             magic_arg_s = self.var_expand(line, stack_depth)
#    2292             with self.builtin_trap:
# -> 2293                 result = fn(magic_arg_s, cell)
#    2294             return result
#    2295
#
# /Users/Flukmacdesof/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#
# /Users/Flukmacdesof/anaconda/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /Users/Flukmacdesof/anaconda/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1165         else:
#    1166             st = clock2()
# -> 1167             exec(code, glob, local_ns)
#    1168             end = clock2()
#    1169             out = None
#
# <timed exec> in <module>()
#
# /Users/Flukmacdesof/anaconda/lib/python2.7/site-packages/sklearn/cross_validation.pyc in cross_val_score(estimator, X, y, scoring, cv, n_jobs, verbose, fit_params, pre_dispatch)
#    1431                                               train, test, verbose, None,
#    1432                                               fit_params)
# -> 1433                       for train, test in cv)
#    1434     return np.array(scores)[:, 0]
#    1435
#
# /Users/Flukmacdesof/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in __call__(self, iterable)
#     810                 # consumption.
#     811                 self._iterating = False
# --> 812             self.retrieve()
#     813             # Make sure that we get a last message telling us we are done
#     814             elapsed_time = time.time() - self._start_time
#
# /Users/Flukmacdesof/anaconda/lib/python2.7/site-packages/sklearn/externals/joblib/parallel.pyc in retrieve(self)
#     760                         # a working pool as they expect.
#     761                         self._initialize_pool()
# --> 762                 raise exception
#     763
#     764     def __call__(self, iterable):
#
# KeyboardInterrupt:

# %%
labels_test.head()
# Out:
#             ID  TARGET
# 3826   ID03827       2
# 23673  ID23674       2
# 18304  ID18305       2
# 2943   ID02944       3
# 8158   ID08159       3

# %%
def make_submission(predicted_label, name = 'submit.csv'):
    ids=labels_test["ID"]
    ids = pd.read_csv('../data/data_sleep/input_test.csv', usecols= ['ID'])
    ids["TARGET"] = pd.Series(predicted_label)
    ids['TARGET']= ids['TARGET'].astype(int)
    ids.to_csv(name,index=False)
    #return ids

# %%
make_submission(predicted_label)

# %%
ids.head()
# Out:
# 3826     ID03827
# 23673    ID23674
# 18304    ID18305
# 2943     ID02944
# 8158     ID08159
# Name: ID, dtype: object

# %%
print("Extra Random Trees - kappa Score on test_data : ", cohen_kappa_score(y_test, predicted_label))

# %%
predicted_label_train = et.predict(X_train)

# %%
import collections
print collections.Counter(predicted_label), collections.Counter(y_train)
# Out:
# Counter({2.0: 26010, 4.0: 2276, 3.0: 1598, 0.0: 493, 1.0: 81}) Counter({2.0: 15334, 3.0: 9640, 4.0: 4385, 0.0: 1342, 1.0: 428})

# %%
X_train.shape, X_test.shape
# Out:
# ((31129, 81), (30458, 81))
